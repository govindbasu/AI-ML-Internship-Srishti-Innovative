# %%
import pandas as pd
data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {
    "Name": ["Rahul", "Arun", "Neha", "Diya"],
    "Age": [20, 21, 19, 22],
    "Marks": [85, 90, 78, 88]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1   Arun   21     90
# 2   Neha   19     78
# 3   Diya   22     88

# %%
print(df.head())
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1   Arun   21     90
# 2   Neha   19     78
# 3   Diya   22     88

# %%
print(df.tail())
# Out:
#     Name  Age  Marks
# 0  Rahul   20     85
# 1   Arun   21     90
# 2   Neha   19     78
# 3   Diya   22     88

# %%
print(df.shape)
# Out:
# (4, 3)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
import pandas as pd

data = {
    "Name": ["Arun", "Rahul", None, "Diya"],
    "Age": [20, None, 19, 22],
    "Marks": [85, 90, None, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name   Age  Marks
# 0   Arun  20.0   85.0
# 1  Rahul   NaN   90.0
# 2   None  19.0    NaN
# 3   Diya  22.0   88.0

# %%
print(df.isnull())
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True
# 3  False  False  False

# %%
print(df.isnull().sum())
# Out:
# Name     1
# Age      1
# Marks    1
# dtype: int64

# %%
new_df = df.dropna()

print(new_df)
# Out:
#    Name   Age  Marks
# 0  Arun  20.0   85.0
# 3  Diya  22.0   88.0

# %%
df.fillna(0, inplace=True)

print(df)
# Out:
#     Name   Age  Marks
# 0   Arun  20.0   85.0
# 1  Rahul   0.0   90.0
# 2      0  19.0    0.0
# 3   Diya  22.0   88.0

# %%
import pandas as pd

data = {
    "Name": ["Arun", "Rahul", None, "Diya"],
    "Age": [20, None, 19, 22],
    "Marks": [85, 90, None, 88]
}

df = pd.DataFrame(data)

print("Original Data")
print(df)

print("\nMissing Values")
print(df.isnull())

print("\nCount Missing Values")
print(df.isnull().sum())

# Fill missing values correctly
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

df["Name"] = df["Name"].fillna("Unknown")

df["Age"] = df["Age"].fillna(df["Age"].mean())

print("\nAfter Filling Missing Values")
print(df)
# Out:
# Original Data
#     Name   Age  Marks
# 0   Arun  20.0   85.0
# 1  Rahul   NaN   90.0
# 2   None  19.0    NaN
# 3   Diya  22.0   88.0
#
# Missing Values
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True
# 3  False  False  False
#
# Count Missing Values
# Name     1
# Age      1
# Marks    1
# dtype: int64
#
# After Filling Missing Values
#       Name        Age      Marks
# 0     Arun  20.000000  85.000000
# 1    Rahul  20.333333  90.000000
# 2  Unknown  19.000000  87.666667
# 3     Diya  22.000000  88.000000
